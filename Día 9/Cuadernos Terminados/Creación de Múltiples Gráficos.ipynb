# %% [markdown]
# # Creación de Múltiples Gráficos
#
# En esta lección vamos a aprender cómo crear múltiples gráficos (también conocidos como *subgráficos* o *subplots*) **dentro de un único *figure*** en Python, utilizando la biblioteca Matplotlib.
#
# Esta habilidad es esencial para la **comparación visual** de diferentes conjuntos de datos o para **mostrar distintos aspectos** de un mismo conjunto de datos.
#
# Vamos a retomar algo que ya hemos visto al comienzo del día, en la lección sobre la **Estructura Principal de Matplotlib**, donde vimos que nuestros gráficos se cuelgan en una pared (o *figura*), y que esa figura puede contener más de un cuadro (o *axes*).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axs = plt.subplots(ncols=2, nrows=2);

# %% [markdown]
# En esta linea he creado una *figura* (que se almacena en la variable `fig`), y dos *axes* (que se almacenan en la variable `axs`, que es un array que los contiene).
#
# Del mismo modo puedo crear otra figura, pero que esta vez solo contenga **dos gráficos**:

# %%
fig, axs = plt.subplots(ncols=2, nrows=1);

# %% [markdown]
# Ahora veamos cómo **indexar** a cada uno de **esos axes**, para poder desplegar **un gráfico distinto en cada uno de ellos**.

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)

ax1 = axs[0]
ax2 = axs[1];

# %% [markdown]
# Con esto, aún no tengo mis gráficos (porque no les he asignado datos), pero ya cuento con **dos variables** que representan, cada una de ellas, un *axes* de mi *figura*.
#
# Vamos a usar esos nombres de variables para desplegar en ellos **dos gráficos diferentes**:

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)

ax1 = axs[0]
ax2 = axs[1]

ax1.plot([1, 2, 3, 4], [1, 4, 9, 16])
ax2.scatter([1, 2, 3, 4], [1, 4, 9, 16]);

# %% [markdown]
# Y por supuesto, puedes seguir usando estos nombres para **agregar cualquier elemento** que te interese incluir en tus gráficos.

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)

ax1 = axs[0]
ax2 = axs[1]

ax1.plot([1, 2, 3, 4], [1, 4, 9, 16])
ax2.scatter([1, 2, 3, 4], [1, 4, 9, 16])

ax1.set_title("Gráfico de Línea")
ax2.set_title("Gráfico Scatter");

# %% [markdown]
# Esto ha sido **cómo crear más de un gráfico en tus figuras**, y estoy seguro de que te será por demás útil en tu carrera.
